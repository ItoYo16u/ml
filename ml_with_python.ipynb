# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import seaborn as sns
cancer = load_breast_cancer()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(
    cancer.data,cancer.target,stratify=cancer.target,random_state = 66
)

# %%
X_train.shape
from sklearn.neighbors import KNeighborsClassifier as knc

# %%
neighbors_settings = range(1,11)
training_accuracy=[]
test_accuracy = []

for n in neighbors_settings:
    clf = knc(n_neighbors = n)
    clf.fit(X_train,y_train)
    training_accuracy.append(clf.score(X_train,y_train))
    test_accuracy.append(clf.score(X_test,y_test))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(neighbors_settings,training_accuracy,label = "train")
ax.plot(neighbors_settings,test_accuracy,label="test")
ax.set_xlabel("neighbors")
ax.set_ylabel("accuracy")
ax.legend()

# %%
import mglearn

# %%
mglearn.plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804

# %%
from sklearn.neighbors import KNeighborsRegressor as knr

# %%
X,y = mglearn.datasets.make_wave(n_samples=40)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)
reg= knr(n_neighbors = 3)
reg.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#           weights='uniform')

# %%
reg.score(X_test,y_test)
# Out:
# 0.8344172446249604

# %%
from sklearn.linear_model import LinearRegression
X, y = mglearn.datasets.make_wave(n_samples = 60)
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=40)

# %%
lr = LinearRegression().fit(X_train,y_train)
lr.coef_,lr.intercept_
# Out:
# (array([0.41903332]), -0.09450848331906847)

# %%
lr.score(X_test,y_test)
# Out:
# 0.7423790374659854

# %%
from sklearn.linear_model import Ridge
rgrg  = Ridge(alpha=0.1).fit(X_train,y_train)
rgrg.score(X_test,y_test)
# Out:
# 0.7423718260290956

# %%
from sklearn.tree import DecisionTreeClassifier as dtc

# %%
cancer = load_breast_cancer()

# %%
X_train,X_test,y_train,y_test = train_test_split(
    cancer.data, cancer.target,stratify = cancer.target, random_state=45
)
tree = dtc(random_state = 0,max_depth=4)
tree.fit(X_train,y_train)
tree.score(X_test,y_test)
# Out:
# 0.9370629370629371

# %%
tree.feature_importances_
# Out:
# array([0.        , 0.02332154, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.07269903, 0.        , 0.        ,
#        0.00999317, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.01028778, 0.03498231, 0.        , 0.        ,
#        0.        , 0.03660875, 0.76144817, 0.        , 0.        ,
#        0.        , 0.        , 0.05065925, 0.        , 0.        ])

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.datasets import make_moons

X,y = make_moons(n_samples=100, noise = 0.25, random_state=3)
X_train,X_test,y_train,y_test = train_test_split(
    X,y,stratify=y, random_state=42
)

# %%
forest = rfc(n_estimators=5, random_state= 2)
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=None,
#             oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
fig,axes= plt.subplots(2,3,figsize=(20,10))
for i,(ax,tree) in enumerate(zip(axes.ravel(),forest.estimators_)):
    ax.set_title("tree{}".format(i))
    mglearn.plots.plot_tree_partition(X_train,y_train,tree,ax=ax)
mglearn.plots.plot_2d_separator(forest,X_train,ax=axes[-1,-1],fill=True,alpha=0.4)
axes[-1,-1].set_title("random forest")
# Out:
# Text(0.5, 1.0, 'random forest')

# %%
tree.score(X_test,y_test)
# Out:
# 0.88

# %%
from sklearn.svm import LinearSVC
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(centers=4, random_state=8)
y = y%2
lsvm=LinearSVC().fit(X,y)

mglearn.discrete_scatter(X[:,0],X[:,1],y)
mglearn.plots.plot_2d_separator(lsvm,X)
plt.xlabel("feature 0")
plt.ylabel("feature 1")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Text(0, 0.5, 'feature 1')

# %%
import numpy as np
X_new = np.hstack([X,X[:,1:]**2])
from mpl_toolkits.mplot3d import Axes3D, axes3d
fig = plt.figure()
ax = Axes3D(fig,elev=-152,azim = -26)
xx= np.linspace(X_new[:,0].min()-2,X_new[:,0].max()+2,50)
yy = np.linspace(X_new[:,1].min()-2,X_new[:,1].max()+2,50)
XX,YY=np.meshgrid(xx,yy)
lsvm3d= LinearSVC().fit(X_new,y)
ZZ= (coef_[0]*XX+coef_[1]**YY + intercept_)/-coef_[2]
ax.plot_surface(XX,YY,ZZ, rstride=8,cstride=8,alpha=0.3)
coef_ , intercept_ = lsvm3d.coef_.ravel(),lsvm3d.intercept_
mask= y==0
ax.scatter(X_new[mask,0],X_new[mask,1],X_new[mask,2],c="b",cmap=mglearn.cm2,s=60)
ax.scatter(X_new[~mask,0],X_new[~mask,1],X_new[~mask,2],c="r",marker="^",cmap=mglearn.cm2,s=60)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4644b7c1aa6b> in <module>
#       8 XX,YY=np.meshgrid(xx,yy)
#       9 lsvm3d= LinearSVC().fit(X_new,y)
# ---> 10 ZZ= (coef_[0]*XX+coef_[1]**YY + intercept_)/-coef_[2]
#      11 ax.plot_surface(XX,YY,ZZ, rstride=8,cstride=8,alpha=0.3)
#      12 coef_ , intercept_ = lsvm3d.coef_.ravel(),lsvm3d.intercept_
#
# NameError: name 'coef_' is not defined

# %%
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.datasets import make_moons

# %%
X,y = make_moons(n_samples=100,noise=0.25,random_state=3)

# %%
X_train,X_test,y_train,y_test= train_test_split(
    X,y,stratify=y,random_state=32
)

# %%
mlp= MLPClassifier(
    solver="lbfgs",
    random_state=0,
    hidden_layer_sizes=[10],
    activation="relu"
).fit(X_train,y_train)
mglearn.plots.plot_2d_separator(
    mlp,
    X_train,
    fill=True,
    alpha=0.3
)
mglearn.discrete_scatter(
    X_train[:,0],X_train[:,1],y_train
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6b942ac9a5b1> in <module>
# ----> 1 mlp= MLPClassifier(
#       2     solver="lbfgs",
#       3     random_state=0,
#       4     hidden_layer_sizes=[10],
#       5     activation="relu"
#
# NameError: name 'MLPClassifier' is not defined

# %%
cancer = load_breast_cancer()

# %%
X_train,X_test,y_train,y_test=train_test_split(
    cancer.data,cancer.target,random_state=1
)
X_train.shape,X_test.shape
# Out:
# ((426, 30), (143, 30))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train_scaled= scaler.transform(X_train)

# %%
X_train_scaled.shape
# Out:
# (426, 30)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
svm = SVC(C=100)

# %%
svm.fit(X_train_scaled,y_train)
svm.score(X_test_scaled,y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.965034965034965

# %%
## signal analysis with nmf and compare the result to that with pca
import mglearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
S = mglearn.datasets.make_signals()

# %%
plt.figure(figsize=(20,10))
plt.plot(S)
S.shape
# Out:
# (2000, 3)

# %%
import numpy as np

# %%
A = np.random.RandomState(0).uniform(size=(100,3))
A.shape
# Out:
# (100, 3)

# %%
X  =np.dot(S, A.T)
plt.plot(X)
# Out:
# [<matplotlib.lines.Line2D at 0x1dd9c73f198>,
#  <matplotlib.lines.Line2D at 0x1dd9c73fac8>,
#  <matplotlib.lines.Line2D at 0x1dd9c73f6a0>,
#  <matplotlib.lines.Line2D at 0x1dd9c73fb00>,
#  <matplotlib.lines.Line2D at 0x1dd9c73fa20>,
#  <matplotlib.lines.Line2D at 0x1dd9c73f6d8>,
#  <matplotlib.lines.Line2D at 0x1dd9c73fc88>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4ef0>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a40f0>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4630>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4400>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4da0>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4cf8>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4b70>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a42e8>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4748>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a42b0>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a40b8>,
#  <matplotlib.lines.Line2D at 0x1dd9c5a4080>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e5f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c83ef60>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e080>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e160>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e8d0>,
#  <matplotlib.lines.Line2D at 0x1dd9c83ee80>,
#  <matplotlib.lines.Line2D at 0x1dd9c83eda0>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e780>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e240>,
#  <matplotlib.lines.Line2D at 0x1dd9c83e588>,
#  <matplotlib.lines.Line2D at 0x1dd9c7adef0>,
#  <matplotlib.lines.Line2D at 0x1dd9c7ad710>,
#  <matplotlib.lines.Line2D at 0x1dd9c7ad860>,
#  <matplotlib.lines.Line2D at 0x1dd9c7adb00>,
#  <matplotlib.lines.Line2D at 0x1dd9c7ad5f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7ad240>,
#  <matplotlib.lines.Line2D at 0x1dd9c7adf60>,
#  <matplotlib.lines.Line2D at 0x1dd9c14f4a8>,
#  <matplotlib.lines.Line2D at 0x1dd9c14f2b0>,
#  <matplotlib.lines.Line2D at 0x1dd9c14f400>,
#  <matplotlib.lines.Line2D at 0x1dd9c14fa58>,
#  <matplotlib.lines.Line2D at 0x1dd9c14fe80>,
#  <matplotlib.lines.Line2D at 0x1dd9c14fda0>,
#  <matplotlib.lines.Line2D at 0x1dd9c14fcf8>,
#  <matplotlib.lines.Line2D at 0x1dd9c14f518>,
#  <matplotlib.lines.Line2D at 0x1dd9c14f6d8>,
#  <matplotlib.lines.Line2D at 0x1dd9c14f5f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c5c9550>,
#  <matplotlib.lines.Line2D at 0x1dd9c0eef60>,
#  <matplotlib.lines.Line2D at 0x1dd9a1426a0>,
#  <matplotlib.lines.Line2D at 0x1dd9a1425c0>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6470>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6748>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6898>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d69e8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6b38>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6c88>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6dd8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7d6f28>,
#  <matplotlib.lines.Line2D at 0x1dd9c8480b8>,
#  <matplotlib.lines.Line2D at 0x1dd9c848208>,
#  <matplotlib.lines.Line2D at 0x1dd9c848358>,
#  <matplotlib.lines.Line2D at 0x1dd9c8484a8>,
#  <matplotlib.lines.Line2D at 0x1dd9c8485f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c848748>,
#  <matplotlib.lines.Line2D at 0x1dd9c848898>,
#  <matplotlib.lines.Line2D at 0x1dd9c8489e8>,
#  <matplotlib.lines.Line2D at 0x1dd9c848b38>,
#  <matplotlib.lines.Line2D at 0x1dd9c848c88>,
#  <matplotlib.lines.Line2D at 0x1dd9c848dd8>,
#  <matplotlib.lines.Line2D at 0x1dd9c848f28>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da0b8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da208>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da358>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da4a8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da5f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da748>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da898>,
#  <matplotlib.lines.Line2D at 0x1dd9c7da9e8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7dab38>,
#  <matplotlib.lines.Line2D at 0x1dd9c7dac88>,
#  <matplotlib.lines.Line2D at 0x1dd9c7dadd8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7daf28>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de0b8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de208>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de358>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de4a8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de5f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de748>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de898>,
#  <matplotlib.lines.Line2D at 0x1dd9c7de9e8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7deb38>,
#  <matplotlib.lines.Line2D at 0x1dd9c7dec88>,
#  <matplotlib.lines.Line2D at 0x1dd9c7dedd8>,
#  <matplotlib.lines.Line2D at 0x1dd9c7def28>,
#  <matplotlib.lines.Line2D at 0x1dd9c75f0b8>,
#  <matplotlib.lines.Line2D at 0x1dd9c75f208>,
#  <matplotlib.lines.Line2D at 0x1dd9c75f358>,
#  <matplotlib.lines.Line2D at 0x1dd9c75f4a8>,
#  <matplotlib.lines.Line2D at 0x1dd9c75f5f8>,
#  <matplotlib.lines.Line2D at 0x1dd9c75f748>]

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components=3,random_state=42)
S = nmf.fit(X)

# %%
X_nmf = nmf.transform(X)

# %%
plt.plot(X_nmf)
# Out:
# [<matplotlib.lines.Line2D at 0x1dd9ca07320>,
#  <matplotlib.lines.Line2D at 0x1dd9ca07470>,
#  <matplotlib.lines.Line2D at 0x1dd9ca075c0>]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3,random_state=33)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=33,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
X_pca = pca.transform(X)

# %%
plt.plot(X_pca)
# Out:
# [<matplotlib.lines.Line2D at 0x1dd9ca73cc0>,
#  <matplotlib.lines.Line2D at 0x1dd9ca73e10>,
#  <matplotlib.lines.Line2D at 0x1dd9ca73f60>]

# %%
from sklearn.datasets import load_digits
digits = load_digits()
fig,axes = plt.subplots(8,8,figsize=(10,10))
for img,ax in zip(digits.images, axes.ravel()):
    ax.imshow(img)

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
digits = load_digits()
pca = PCA(n_components = 2)
pca.fit(digits.data)
digits_pca = pca.transform(digits.data)
# Out:
# (1797, 2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(10,10))
for i in range(1000):
    plt.text(digits_pca[i][0],digits_pca[i][1],str(digits.target[i]))
